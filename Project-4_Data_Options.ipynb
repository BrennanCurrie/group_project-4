# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %%
# OPTION 1: Alcohol Consumption
# Import and read in data

alchol_classification_df = pd.read_csv("/Users/brennancurrie/Desktop/My_Code/My_Repos/group_project-4/Discovery_Resources/Alcohol_Consumption/Alch_Consumption_By_Country.csv")
alchol_classification_df.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings
# 0  Afghanistan              0                0              0  \
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
df = pd.read_csv("/Users/brennancurrie/Desktop/My_Code/My_Repos/group_project-4/Discovery_Resources/Alcohol_Consumption/World Alcoholic Consumption datasets.csv")
df.head(5)
# Out:
#    Gender  Count       Countries Countries Code        Date
# 0  Female      1           Japan             JP  12/25/2019
# 1  Female      2  Czech Republic             CZ  12/22/2019
# 2    Male      3        Portugal             PT  12/28/2019
# 3  Female      4     Netherlands             NL    12-01-19
# 4  Female      5       Argentina             AR  12/24/2019

# %%
##############################################################################################################

# %%
#OPTION 2: Pet Age / Pet Facial Expression

#leaving this blank as we have classified image files, figuring out how to import these

# %%
##############################################################################################################

# %%
#OPTION 3: Used Car Values

used_train_df = pd.read_csv("/Users/brennancurrie/Desktop/My_Code/My_Repos/group_project-4/Discovery_Resources/Used_Car_Value/used_car_train.csv")
used_train_df.head(5)
# Out:
#    Unnamed: 0          id    year manufacturer     model  condition
# 0      121610  7309831550  2007.0     infiniti       m45  excellent  \
# 1      395646  7317007429  2008.0     cadillac  escalade        NaN
# 2      236366  7309202024  2003.0        lexus        es        NaN
# 3       66001  7306341714  2017.0          bmw      320i  excellent
# 4      320855  7307880118  2008.0       toyota      rav4       good
#
#      cylinders fuel  odometer title_status transmission drive       size
# 0          NaN  gas  214740.0        clean    automatic   rwd        NaN  \
# 1          NaN  gas  170276.0        clean    automatic   NaN        NaN
# 2          NaN  gas  176910.0        clean    automatic   fwd        NaN
# 3          NaN  gas   41000.0        clean    automatic   4wd        NaN
# 4  6 cylinders  gas  138900.0        clean    automatic   4wd  full-size
#
#     type paint_color state        lat        long              posting_date
# ...

# %%
used_test_df = pd.read_csv("/Users/brennancurrie/Desktop/My_Code/My_Repos/group_project-4/Discovery_Resources/Used_Car_Value/used_car_test.csv")
used_test_df.head(5)
# Out:
#    Unnamed: 0          id    year manufacturer                       model
# 0      316575  7313399730  2018.0        honda                       civic  \
# 1       97903  7308035814  2017.0     cadillac     cts 2.0 luxury sedan 4d
# 2      357880  7317063645  2006.0       toyota                      sienna
# 3      413008  7310376764  2016.0   mitsubishi         outlander sel sport
# 4      330300  7309848062  2017.0         audi  a6 3.0t premium plus sedan
#
#    condition    cylinders   fuel  odometer title_status transmission drive
# 0        NaN  4 cylinders    gas   28898.0        clean    automatic   fwd  \
# 1       good          NaN    gas   41147.0        clean        other   NaN
# 2  excellent  6 cylinders    gas  165500.0        clean    automatic   NaN
# 3       good          NaN  other   29430.0        clean        other   NaN
# 4       good  6 cylinders    gas   24238.0        clean    automatic   NaN
#
#   size      type paint_color state        lat        long
# ...

# %%
##############################################################################################################

# %%
#OPTION 4: What Barbie are you

barbie_char_df = pd.read_csv("/Users/brennancurrie/Desktop/My_Code/My_Repos/group_project-4/Discovery_Resources/Barbie/Barbieverse Characters.csv")
barbie_char_df.head(5)
# Out:
#    No.  Movie  No. Character            Character Name      Barbie Cast
# 0           1              1                    Barbie           Barbie  \
# 1           1              2         Aunt Drosselmayer              NaN
# 2           1              3             Captain Candy              NaN
# 3           1              4                     Clara           Barbie
# 4           1              5            Flower Faeries              NaN
# 5           1              6           Gingerbread Boy            Tommy
# 6           1              7  Grandfather Drosselmayer              NaN
# 7           1              8                     Kelly  Kelly / Chelsea
# 8           1              9                      Maid              NaN
# 9           1             10                Major Mint              NaN
#
#       Skin Tone        Eyes         Hair  Gender          Race
# 0  Light Medium        Blue       Blonde  Female         Human  \
# ...

# %%
barbie_mov_df = pd.read_csv("/Users/brennancurrie/Desktop/My_Code/My_Repos/group_project-4/Discovery_Resources/Barbie/Barbieverse Movies.csv")
barbie_mov_df.head(5)
# Out:
#    No. Movie                              Movie Title Release Date
# 0          1                 Barbie in the Nutcracker   02/10/2001  \
# 1          2                       Barbie as Rapunzel   01/10/2002
# 2          3                      Barbie of Swan Lake   30/09/2003
# 3          4    Barbie as The Princess and the Pauper   28/09/2004
# 4          5                        Barbie Fairytopia   08/03/2005
# 5          6          Barbie and the Magic of Pegasus   20/09/2005
# 6          7             Barbie Fairytopia: Mermaidia   14/03/2006
# 7          8                       The Barbie Diaries   09/05/2006
# 8          9      Barbie in The 12 Dancing Princesses   19/09/2003
# 9         10  Barbie Fairytopia: Magic of the Rainbow   13/03/2007
#
#                     Era                           Ending Credits Quote
# 0  Adaptations &Testing                                      No quote.  \
# 1  Adaptations &Testing   "Love and imagination can change the world."
# ...
